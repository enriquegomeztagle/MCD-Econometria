# %%
# %pip install pandas matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
try:
    df = pd.read_excel("../data/cableTV.xlsx")
    print("File read successfully")
    read_success = True
except Exception as e:
    print(f"Error while reading the file: {e}")
# Out:
# File read successfully

# %%
if read_success:
    print("--------------------------------")
    print("Dataframe head:")
    print(df.head(10))
# Out:
# --------------------------------
# Dataframe head:
#    obs  colonia  manzana  adultos  ninos  teles  renta  tvtot tipo   valor
# 0    1        2       20        3      2      2     50     68    B   79928
# 1    2        2       25        3      3      1     65     82    B   94415
# 2    3        2       20        1      2      1     45     40    A  120896
# 3    4        2        8        2      2      2     35     56    A  132867
# 4    5        2       25        1      2      0      0      0    N  141901
# 5    6        2       14        1      2      0      0      0    N  147997
# 6    7        2       22        2      1      1     65     30    A  156410
# 7    8        2       20        3      1      3     45     62    C  156841
# 8    9        2       25        3      3      2     70     82    A  157041
# 9   10        2       20        2      2      3     45     60    C  161222

# %%
if read_success:
    print("--------------------------------")
    print("Dataframe info:")
    print(df.info())
# Out:
# --------------------------------
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   obs      40 non-null     int64
#  1   colonia  40 non-null     int64
#  2   manzana  40 non-null     int64
#  3   adultos  40 non-null     int64
#  4   ninos    40 non-null     int64
#  5   teles    40 non-null     int64
#  6   renta    40 non-null     int64
#  7   tvtot    40 non-null     int64
#  8   tipo     40 non-null     object
#  9   valor    40 non-null     int64
# dtypes: int64(9), object(1)
# memory usage: 3.3+ KB
# None

# %%
if read_success:
    print("--------------------------------")
    print("Dataframe describe:")
    print(df.describe())
# Out:
# --------------------------------
# Dataframe describe:
#              obs   colonia    manzana    adultos      ninos      teles  \
# count  40.000000  40.00000  40.000000  40.000000  40.000000  40.000000
# mean   20.500000   1.62500  13.000000   2.375000   1.475000   2.450000
# std    11.690452   0.49029   8.149249   0.896932   1.061868   1.218448
# min     1.000000   1.00000   2.000000   1.000000   0.000000   0.000000
# 25%    10.750000   1.00000   7.000000   2.000000   1.000000   1.750000
# 50%    20.500000   2.00000  11.500000   2.000000   1.500000   3.000000
# 75%    30.250000   2.00000  20.500000   3.000000   2.000000   3.000000
# max    40.000000   2.00000  25.000000   4.000000   3.000000   5.000000
#
#            renta      tvtot          valor
# count  40.000000  40.000000      40.000000
# mean   58.250000  43.975000  227966.275000
# std    17.778913  24.132633   77290.275922
# min     0.000000   0.000000   79928.000000
# 25%    50.000000  27.750000  162187.250000
# 50%    62.500000  39.000000  216393.000000
# 75%    70.000000  63.500000  284261.750000
# max    85.000000  86.000000  370325.000000

# %%
if read_success:
    print("--------------------------------")
    print("Dataframe shape:")
    print(df.shape)
# Out:
# --------------------------------
# Dataframe shape:
# (40, 10)

# %%
if read_success:
    print("--------------------------------")
    print("Dataframe missing values:")
    print(df.isnull().sum())
    print("--------------------------------")
    print("Dataframe unique values:")
    print(df.nunique())
# Out:
# --------------------------------
# Dataframe missing values:
# obs        0
# colonia    0
# manzana    0
# adultos    0
# ninos      0
# teles      0
# renta      0
# tvtot      0
# tipo       0
# valor      0
# dtype: int64
# --------------------------------
# Dataframe unique values:
# obs        40
# colonia     2
# manzana     8
# adultos     4
# ninos       4
# teles       6
# renta      12
# tvtot      29
# tipo        4
# valor      40
# dtype: int64

# %%
if read_success:
    print("--------------------------------")
    print("Dataframe unique values:")
    print(df.nunique())
# Out:
# --------------------------------
# Dataframe unique values:
# obs        40
# colonia     2
# manzana     8
# adultos     4
# ninos       4
# teles       6
# renta      12
# tvtot      29
# tipo        4
# valor      40
# dtype: int64

# %%
quant_vars = ["adultos", "ninos", "teles", "tvtot", "renta", "valor"]
for var in quant_vars:
    plt.figure(figsize=(8, 5))
    values = df[var]
    label = var
    if var == "valor":
        values = values / 1000
        label += " (thousands of pesos)"
    plt.hist(values, bins="auto", edgecolor="black")
    plt.xlabel(label)
    plt.ylabel("Frequency")
    plt.title(f"Frequency of {label}")
    plt.grid(True, linestyle="--", alpha=0.5)
    plt.tight_layout()
    plt.savefig(f"../plots/jupyter/freq_{var}.png", dpi=300, bbox_inches="tight")
    plt.show()
    plt.close()

# %%
cat_vars = ["colonia", "tipo"]
for var in cat_vars:
    print(f"=== Frequency of '{var}' ===")
    print(df[var].value_counts(dropna=False))
    print()
# Out:
# === Frequency of 'colonia' ===
# colonia
# 2    25
# 1    15
# Name: count, dtype: int64
#
# === Frequency of 'tipo' ===
# tipo
# C    24
# A    10
# B     4
# N     2
# Name: count, dtype: int64
